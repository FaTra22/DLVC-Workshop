# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
% cd drive/MyDrive/DLVC-Workshop/

! git pull
# Out:
# /content/drive/MyDrive/DLVC-Workshop
# Already up to date.

# %%
import torch
import torch.nn as nn
import numpy as np
np.random.seed(0)
torch.manual_seed(0)

# %% [markdown]
# # 4. Image Classification
#
# Now we have nearly all it takes to train our model.
#
# ### Oh, wait - the model?

# %% [markdown]
# ## 4.1 Neural Network in PyTorch
#
# There are different ways to define a neural network in PyTorch. Since we start with a small network we stick to a simple method: Creating a pytorch.nn.Module Class!
#
#
# ### Archtiecture
#
# 1. Block
# - Convolutional Layer (3,3), stride=1, padding=1, output_channels=32
# - ReLU
# - Convolutional Layer (3,3), stride=1, padding=1, output_channels=32
# - ReLU
# - MaxPooling (2,2)
#
# 2. Block
# - Convolutional Layer (3,3), stride=1, padding=1, output_channels=64
# - ReLU
# - Convolutional Layer (3,3), stride=1, padding=1, output_channels=64
# - ReLU
# - MaxPooling (2,2)
#
# 3. Block
# - Fully Connected Linear Layer

# %%
class SimpleNet(nn.Module):
    def __init__(self, img_size, num_classes):
        super(SimpleNet, self).__init__()
        self.img_size = img_size

        # Instantiate the ReLU nonlinearity
        self.relu = nn.ReLU()

        # Instantiate two convolutional blocks
        ## Block 1
        self.conv1_1 = nn.Conv2d(
            in_channels=3, out_channels=32, kernel_size=3, padding=1)
        self.conv1_2 = nn.Conv2d(
            in_channels=32, out_channels=32, kernel_size=3, padding=1)
        ## Block 2
        self.conv2_1 = nn.Conv2d(
            in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.conv2_2 = nn.Conv2d(
            in_channels=64, out_channels=64, kernel_size=3, padding=1)

        # Instantiate a max pooling layer
        self.pool = nn.MaxPool2d(2, 2)

        ## Block 3
        # Instantiate a fully connected layer
        self.fc = nn.Linear(
            int(img_size[0] / 2 / 2 * img_size[1] / 2 / 2 * 64), num_classes)

    def forward(self, x):
        # Apply block 1 followed by max pool
        x = self.relu(self.conv1_1(x))
        x = self.relu(self.conv1_2(x))
        x = self.pool(x)

        # Apply block 2followed by max pool
        x = self.relu(self.conv2_1(x))
        x = self.relu(self.conv2_2(x))
        x = self.pool(x)
        # Prepare the image for the fully connected layer
        x = x.view(-1, int(64 * 32 / 2 / 2 * 32 / 2 / 2))

        # Apply the fully connected layer and return the result
        return self.fc(x)

# %% [markdown]
# ### Get Model Instance
#
# In order to do that we first need to know the shape of our images. Therefore we use the same functionallity as before to loas the CIFAR-10 Dataset

# %%
from dlvc.datasets.cifar import Cifar10
from dlvc.dataset import Subset
import dlvc.ops as ops
from dlvc.batches import BatchGenerator

DATA_PATH = "./cifar-10-batches-py/"
train_data = Cifar10(DATA_PATH, Subset.TRAINING)
val_data = Cifar10(DATA_PATH, Subset.VALIDATION)
test_data = Cifar10(DATA_PATH, Subset.TEST)

# %%
op = ops.chain([
    ops.type_cast(np.float32),
    ops.add(-127.5),
    ops.mul(1 / 127.5),
    ops.hwc2chw()
])

train_batches = BatchGenerator(train_data, 128, False, op)
val_batches = BatchGenerator(val_data, 128, False, op)
test_batches = BatchGenerator(test_data, 128, False, op)

# %%
img_shape = train_data.image_shape()
num_classes = train_data.num_classes()

net = SimpleNet(img_shape, num_classes).cuda()

# %%
net
# Out:
# SimpleNet(
#   (relu): ReLU()
#   (conv1_1): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv1_2): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2_1): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2_2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc): Linear(in_features=4096, out_features=10, bias=True)
# )

# %% [markdown]
# ## 4.2 Model Training
#
# In order to train our model we still need to define two things:
#
# 1. The Loss Function
#
# We stick to the simple but effective Cross Entropy Loss
#
# 2. The Optimizer
#
# You Probably all have heard about Stochastic Gradient Descent (SGD)

# %% [markdown]
# ### 4.2.1 Cross Entropy Loss
#
# The Cross Entropy Loss, or Log Loss, measures the performance of a classifier which outputs class probabilites for every class
#
# ![cnn](https://github.com/FaTra22/DLVC-Workshop/blob/main/images/cross_entropy.png?raw=1)
#
# [Source](https://ml-cheatsheet.readthedocs.io/en/latest/loss_functions.html)

# %%
# load the loss function from PyTorch
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# ### 4.2.2 Stochastic Gradient Descent
#
# Update the parameters of the network according to the Gradient (Derivation at a certain point).
#
# A lot of information about this - just accept as a fact that this works for now ^^

# %%
learning_rate = 0.01
weight_decay = 0

optimizer = torch.optim.SGD(
            net.parameters(), 
            lr=learning_rate, 
            weight_decay=weight_decay, 
            nesterov=True, 
            momentum=0.9)


def get_prediction(row):             
    return np.argmax(row)

# %% [markdown]
# ## Finally, train that boy
#
# Iterate over every batch in the training examples and train the model using the labels

# %%
net.train()

num_correct_predictions = 0
num_predictions = 0
count = 0
for batch in train_batches:
    print("Batch #{}".format(count))
    data = batch.data
    labels = batch.label

    optimizer.zero_grad()

    inputs = torch.from_numpy(data).cuda()
    label = torch.from_numpy(labels).long().cuda()

    outputs = net(inputs)

    loss = criterion(outputs, label)
    loss.backward()

    optimizer.step()
    count += 1

    predictions = np.apply_along_axis(get_prediction, 1, outputs.cpu().detach().numpy())
    correct_predictions = np.sum(predictions == labels)
    num_correct_predictions += correct_predictions
    num_predictions += len(predictions)
print("Training Accurcay >>> {}%".format(round(100*num_correct_predictions/num_predictions, 2)))
# Out:
# Batch #0
# Batch #1
# Batch #2
# Batch #3
# Batch #4
# Batch #5
# Batch #6
# Batch #7
# Batch #8
# Batch #9
# Batch #10
# Batch #11
# Batch #12
# Batch #13
# Batch #14
# Batch #15
# Batch #16
# Batch #17
# Batch #18
# Batch #19
# Batch #20
# Batch #21
# Batch #22
# Batch #23
# Batch #24
# Batch #25
# Batch #26
# Batch #27
# Batch #28
# Batch #29
# Batch #30
# Batch #31
# Batch #32
# Batch #33
# Batch #34
# Batch #35
# Batch #36
# Batch #37
# Batch #38
# Batch #39
# Batch #40
# Batch #41
# Batch #42
# Batch #43
# Batch #44
# Batch #45
# Batch #46
# Batch #47
# Batch #48
# Batch #49
# Batch #50
# Batch #51
# Batch #52
# Batch #53
# Batch #54
# Batch #55
# Batch #56
# Batch #57
# Batch #58
# Batch #59
# Batch #60
# Batch #61
# Batch #62
# Batch #63
# Batch #64
# Batch #65
# Batch #66
# Batch #67
# Batch #68
# Batch #69
# Batch #70
# Batch #71
# Batch #72
# Batch #73
# Batch #74
# Batch #75
# Batch #76
# Batch #77
# Batch #78
# Batch #79
# Batch #80
# Batch #81
# Batch #82
# Batch #83
# Batch #84
# Batch #85
# Batch #86
# Batch #87
# Batch #88
# Batch #89
# Batch #90
# Batch #91
# Batch #92
# Batch #93
# Batch #94
# Batch #95
# Batch #96
# Batch #97
# Batch #98
# Batch #99
# Batch #100
# Batch #101
# Batch #102
# Batch #103
# Batch #104
# Batch #105
# Batch #106
# Batch #107
# Batch #108
# Batch #109
# Batch #110
# Batch #111
# Batch #112
# Batch #113
# Batch #114
# Batch #115
# Batch #116
# Batch #117
# Batch #118
# Batch #119
# Batch #120
# Batch #121
# Batch #122
# Batch #123
# Batch #124
# Batch #125
# Batch #126
# Batch #127
# Batch #128
# Batch #129
# Batch #130
# Batch #131
# Batch #132
# Batch #133
# Batch #134
# Batch #135
# Batch #136
# Batch #137
# Batch #138
# Batch #139
# Batch #140
# Batch #141
# Batch #142
# Batch #143
# Batch #144
# Batch #145
# Batch #146
# Batch #147
# Batch #148
# Batch #149
# Batch #150
# Batch #151
# Batch #152
# Batch #153
# Batch #154
# Batch #155
# Batch #156
# Batch #157
# Batch #158
# Batch #159
# Batch #160
# Batch #161
# Batch #162
# Batch #163
# Batch #164
# Batch #165
# Batch #166
# Batch #167
# Batch #168
# Batch #169
# Batch #170
# Batch #171
# Batch #172
# Batch #173
# Batch #174
# Batch #175
# Batch #176
# Batch #177
# Batch #178
# Batch #179
# Batch #180
# Batch #181
# Batch #182
# Batch #183
# Batch #184
# Batch #185
# Batch #186
# Batch #187
# Batch #188
# Batch #189
# Batch #190
# Batch #191
# Batch #192
# Batch #193
# Batch #194
# Batch #195
# Batch #196
# Batch #197
# Batch #198
# Batch #199
# Batch #200
# Batch #201
# Batch #202
# Batch #203
# Batch #204
# Batch #205
# Batch #206
# Batch #207
# Batch #208
# Batch #209
# Batch #210
# Batch #211
# Batch #212
# Batch #213
# Batch #214
# Batch #215
# Batch #216
# Batch #217
# Batch #218
# Batch #219
# Batch #220
# Batch #221
# Batch #222
# Batch #223
# Batch #224
# Batch #225
# Batch #226
# Batch #227
# Batch #228
# Batch #229
# Batch #230
# Batch #231
# Batch #232
# Batch #233
# Batch #234
# Batch #235
# Batch #236
# Batch #237
# Batch #238
# Batch #239
# Batch #240
# Batch #241
# Batch #242
# Batch #243
# Batch #244
# Batch #245
# Batch #246
# Batch #247
# Batch #248
# Batch #249
# Batch #250
# Batch #251
# Batch #252
# Batch #253
# Batch #254
# Batch #255
# Batch #256
# Batch #257
# Batch #258
# Batch #259
# Batch #260
# Batch #261
# Batch #262
# Batch #263
# Batch #264
# Batch #265
# Batch #266
# Batch #267
# Batch #268
# Batch #269
# Batch #270
# Batch #271
# Batch #272
# Batch #273
# Batch #274
# Batch #275
# Batch #276
# Batch #277
# Batch #278
# Batch #279
# Batch #280
# Batch #281
# Batch #282
# Batch #283
# Batch #284
# Batch #285
# Batch #286
# Batch #287
# Batch #288
# Batch #289
# Batch #290
# Batch #291
# Batch #292
# Batch #293
# Batch #294
# Batch #295
# Batch #296
# Batch #297
# Batch #298
# Batch #299
# Batch #300
# Batch #301
# Batch #302
# Batch #303
# Batch #304
# Batch #305
# Batch #306
# Batch #307
# Batch #308
# Batch #309
# Batch #310
# Batch #311
# Batch #312
# Training Accurcay >>> 33.13%

# %% [markdown]
# ### Predict Image-Class using the Model
#
# We can now use the model in the same way to predict new images.
#
# There are slight differences during training and predicting:
#
# - Gradient Calculation is not needed
#
# - Behaviour of certain layers
#
#     e.g.: Dropout Layer
#
# #### Test-Set
#
# For now we use our validation set for this simple test.

# %%
net.eval() # behaviour of layer
num_predictions = 0
num_correct_predictions = 0
with torch.no_grad(): # no gradients
    for batch in val_batches:
        data = batch.data
        labels = batch.label

        inputs = torch.from_numpy(data).cuda()

        outputs = net(inputs)
        predictions = np.apply_along_axis(get_prediction, 1, outputs.cpu())
        correct_predictions = np.sum(predictions == labels)
        num_correct_predictions += correct_predictions
        num_predictions += len(predictions)

print("Accuracy >>> {}%".format(round(100*num_correct_predictions/num_predictions, 2)))
# Out:
# Accuracy >>> 47.33%

# %% [markdown]
# ### Not that bad for a simple network with only one Training Epoch

# %% [markdown]
# ## Adding more Epochs
#
# This is very simple by just adding a for loop to repeat the training of the network with the same batches.

# %%
EPOCHS = 10

train_accuracies = []
val_accuracies = []

for i in range(EPOCHS-1):
    print("Epoch #{}".format(i+2))
    num_predictions = 0
    num_correct_predictions = 0

    net.train()
    for batch in train_batches:
        data = batch.data
        labels = batch.label

        optimizer.zero_grad()

        inputs = torch.from_numpy(data).cuda()
        label = torch.from_numpy(labels).long().cuda()

        outputs = net(inputs)
        loss = criterion(outputs, label)
        loss.backward()
        optimizer.step()

        predictions = np.apply_along_axis(get_prediction, 1, outputs.cpu().detach().numpy())
        correct_predictions = np.sum(predictions == labels)
        num_correct_predictions += correct_predictions
        num_predictions += len(predictions)
    print("Training Accurcay >>> {}%".format(round(100*num_correct_predictions/num_predictions, 2)))
    train_accuracies.append(num_correct_predictions/num_predictions)
    
    # Validation during training
    num_predictions = 0
    num_correct_predictions = 0

    net.eval()
    with torch.no_grad():
        for val_batch in val_batches:
            data = val_batch.data
            labels = val_batch.label

            inputs = torch.from_numpy(data).cuda()

            outputs = net(inputs)
            predictions = np.apply_along_axis(get_prediction, 1, outputs.cpu().detach())
            correct_predictions = np.sum(predictions == labels)
            num_correct_predictions += correct_predictions
            num_predictions += len(predictions)
    print("Validation Accurcay >>> {}%".format(round(100*num_correct_predictions/num_predictions, 2)))
    val_accuracies.append(num_correct_predictions/num_predictions)
# Out:
# Epoch #2
# Training Accurcay >>> 53.36%
# Validation Accurcay >>> 53.06%
# Epoch #3
# Training Accurcay >>> 62.35%
# Validation Accurcay >>> 60.9%
# Epoch #4
# Training Accurcay >>> 68.06%
# Validation Accurcay >>> 66.77%
# Epoch #5
# Training Accurcay >>> 71.81%
# Validation Accurcay >>> 69.66%
# Epoch #6
# Training Accurcay >>> 74.62%
# Validation Accurcay >>> 71.43%
# Epoch #7
# Training Accurcay >>> 77.29%
# Validation Accurcay >>> 72.07%
# Epoch #8
# Training Accurcay >>> 79.44%
# Validation Accurcay >>> 72.4%
# Epoch #9
# Training Accurcay >>> 81.54%
# Validation Accurcay >>> 72.14%
# Epoch #10
# Training Accurcay >>> 83.31%
# Validation Accurcay >>> 71.8%

# %%
import matplotlib.pyplot as plt

line1 = plt.plot(train_accuracies, color="r", label="Train")
line2 = plt.plot(val_accuracies, color="g", label="Validaiton")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.show()

# %% [markdown]
# ## And here comes Overfitting
#
# ### Data Augmentation to the rescue!
#
#
# We can reuse the operation chain defined above and add some data augmenatation functions.
#
#
# 1. Shuffle the data every epoch
#
# 2. flip image horiontally with 50% probability
#
# 3. Crop the images by first padding the borders and then get the same size

# %%
import dlvc.ops as ops

op_augmentation = ops.chain([
    ops.type_cast(np.float32),
    ops.add(-127.5),
    ops.mul(1 / 127.5),
    ops.hflip(),
    ops.rcrop(35, 5, 'edge'),
    ops.add_noise(),
    ops.rotate_image(),
    ops.hwc2chw()
])

train_batches_augmented = BatchGenerator(train_data, 128, True, op_augmentation)

ops_rev = ops.chain([
    ops.chw2hwc(),
    ops.mul(127.5),
    ops.add(127.5),
    ops.type_cast(np.int64)
])

for batch in train_batches_augmented:
    data = batch.data
    break


for i in range(5):
    plt.figure()
    print(data[i].shape)

    image_original = ops_rev(data[i])
    plt.imshow(image_original)
    plt.show()
# Out:
# (3, 35, 35)
# (3, 35, 35)
# (3, 35, 35)
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (3, 35, 35)
# (3, 35, 35)

# %%
import torchvision.models as models

#augmented_net = models.resnet18(pretrained=True).cuda()


augmented_net = SimpleNet(img_shape, num_classes).cuda()

optimizer = torch.optim.SGD(
            augmented_net.parameters(), 
            lr=learning_rate, 
            weight_decay=weight_decay, 
            nesterov=True, 
            momentum=0.9)


EPOCHS = 100

train_accuracies = []
val_accuracies = []

best_acc = 0

for i in range(EPOCHS):
    print("Epoch #{}".format(i+1))
    num_predictions = 0
    num_correct_predictions = 0

    augmented_net.train()
    for batch in train_batches_augmented:
        data = batch.data
        labels = batch.label

        optimizer.zero_grad()

        inputs = torch.from_numpy(data).cuda()
        label = torch.from_numpy(labels).long().cuda()

        outputs = augmented_net(inputs)
        loss = criterion(outputs, label)
        loss.backward()
        optimizer.step()

        predictions = np.apply_along_axis(get_prediction, 1, outputs.cpu().detach().numpy())
        correct_predictions = np.sum(predictions == labels)
        num_correct_predictions += correct_predictions
        num_predictions += len(predictions)
    print("Training Accurcay >>> {}%".format(round(100*num_correct_predictions/num_predictions, 2)))
    train_accuracies.append(num_correct_predictions/num_predictions)
    
    # Validation during training
    num_predictions = 0
    num_correct_predictions = 0

    augmented_net.eval()
    with torch.no_grad():
        for val_batch in val_batches:
            data = val_batch.data
            labels = val_batch.label

            inputs = torch.from_numpy(data).cuda()

            outputs = augmented_net(inputs)
            predictions = np.apply_along_axis(get_prediction, 1, outputs.cpu().detach())
            correct_predictions = np.sum(predictions == labels)
            num_correct_predictions += correct_predictions
            num_predictions += len(predictions)
        if num_correct_predictions/num_predictions > best_acc:
            torch.save(augmented_net.state_dict(), "SimpleNet.net".format(i, round(100*num_correct_predictions/num_predictions)))
            best_acc = num_correct_predictions/num_predictions

    print("Validation Accurcay >>> {}%".format(round(100*num_correct_predictions/num_predictions, 2)))
    val_accuracies.append(num_correct_predictions/num_predictions)
# Out:
# Epoch #1
# Training Accurcay >>> 15.16%
# Validation Accurcay >>> 22.94%
# Epoch #2
# Training Accurcay >>> 36.22%
# Validation Accurcay >>> 44.78%
# Epoch #3
# Training Accurcay >>> 48.84%
# Validation Accurcay >>> 51.87%
# Epoch #4
# Training Accurcay >>> 56.42%
# Validation Accurcay >>> 57.4%
# Epoch #5
# Training Accurcay >>> 61.26%
# Validation Accurcay >>> 61.45%
# Epoch #6
# Training Accurcay >>> 64.99%
# Validation Accurcay >>> 63.73%
# Epoch #7
# Training Accurcay >>> 67.22%
# Validation Accurcay >>> 64.81%
# Epoch #8
# Training Accurcay >>> 69.22%
# Validation Accurcay >>> 68.17%
# Epoch #9
# Training Accurcay >>> 70.92%
# Validation Accurcay >>> 68.62%
# Epoch #10
# Training Accurcay >>> 72.25%
# Validation Accurcay >>> 69.72%
# Epoch #11
# Training Accurcay >>> 73.32%
# Validation Accurcay >>> 71.44%
# Epoch #12
# Training Accurcay >>> 74.15%
# Validation Accurcay >>> 72.43%
# Epoch #13
# Training Accurcay >>> 75.0%
# Validation Accurcay >>> 73.13%
# Epoch #14
# Training Accurcay >>> 75.72%
# Validation Accurcay >>> 73.65%
# Epoch #15
# Training Accurcay >>> 76.45%
# Validation Accurcay >>> 74.49%
# Epoch #16
# Training Accurcay >>> 76.91%
# Validation Accurcay >>> 75.31%
# Epoch #17
# Training Accurcay >>> 77.8%
# Validation Accurcay >>> 75.25%
# Epoch #18
# Training Accurcay >>> 78.15%
# Validation Accurcay >>> 74.65%
# Epoch #19
# Training Accurcay >>> 78.27%
# Validation Accurcay >>> 76.45%
# Epoch #20
# Training Accurcay >>> 78.87%
# Validation Accurcay >>> 75.87%
# Epoch #21
# Training Accurcay >>> 79.46%
# Validation Accurcay >>> 76.19%
# Epoch #22
# Training Accurcay >>> 79.68%
# Validation Accurcay >>> 76.08%
# Epoch #23
# Training Accurcay >>> 79.81%
# Validation Accurcay >>> 76.73%
# Epoch #24
# Training Accurcay >>> 80.27%
# Validation Accurcay >>> 77.47%
# Epoch #25
# Training Accurcay >>> 80.74%
# Validation Accurcay >>> 77.08%
# Epoch #26
# Training Accurcay >>> 80.61%
# Validation Accurcay >>> 78.06%
# Epoch #27
# Training Accurcay >>> 81.1%
# Validation Accurcay >>> 78.03%
# Epoch #28
# Training Accurcay >>> 81.31%
# Validation Accurcay >>> 79.07%
# Epoch #29
# Training Accurcay >>> 81.64%
# Validation Accurcay >>> 78.75%
# Epoch #30
# Training Accurcay >>> 81.86%
# Validation Accurcay >>> 78.58%
# Epoch #31
# Training Accurcay >>> 82.01%
# Validation Accurcay >>> 78.95%
# Epoch #32
# Training Accurcay >>> 82.18%
# Validation Accurcay >>> 79.41%
# Epoch #33
# Training Accurcay >>> 82.34%
# Validation Accurcay >>> 79.61%
# Epoch #34
# Training Accurcay >>> 82.45%
# Validation Accurcay >>> 78.89%
# Epoch #35
# Training Accurcay >>> 82.64%
# Validation Accurcay >>> 79.64%
# Epoch #36
# Training Accurcay >>> 83.0%
# Validation Accurcay >>> 78.61%
# Epoch #37
# Training Accurcay >>> 82.86%
# Validation Accurcay >>> 78.83%
# Epoch #38
# Training Accurcay >>> 83.14%
# Validation Accurcay >>> 79.91%
# Epoch #39
# Training Accurcay >>> 83.28%
# Validation Accurcay >>> 79.81%
# Epoch #40
# Training Accurcay >>> 83.47%
# Validation Accurcay >>> 80.54%
# Epoch #41
# Training Accurcay >>> 83.51%
# Validation Accurcay >>> 79.09%
# Epoch #42
# Training Accurcay >>> 83.7%
# Validation Accurcay >>> 79.61%
# Epoch #43
# Training Accurcay >>> 83.66%
# Validation Accurcay >>> 79.94%
# Epoch #44
# Training Accurcay >>> 84.0%
# Validation Accurcay >>> 80.32%
# Epoch #45
# Training Accurcay >>> 84.08%
# Validation Accurcay >>> 80.32%
# Epoch #46
# Training Accurcay >>> 84.19%
# Validation Accurcay >>> 79.6%
# Epoch #47
# Training Accurcay >>> 84.47%
# Validation Accurcay >>> 79.83%
# Epoch #48
# Training Accurcay >>> 84.6%
# Validation Accurcay >>> 80.58%
# Epoch #49
# Training Accurcay >>> 84.5%
# Validation Accurcay >>> 80.2%
# Epoch #50
# Training Accurcay >>> 84.39%
# Validation Accurcay >>> 80.13%
# Epoch #51
# Training Accurcay >>> 84.86%
# Validation Accurcay >>> 80.52%
# Epoch #52
# Training Accurcay >>> 84.67%
# Validation Accurcay >>> 80.74%
# Epoch #53
# Training Accurcay >>> 85.18%
# Validation Accurcay >>> 80.62%
# Epoch #54
# Training Accurcay >>> 85.08%
# Validation Accurcay >>> 80.56%
# Epoch #55
# Training Accurcay >>> 85.04%
# Validation Accurcay >>> 80.29%
# Epoch #56
# Training Accurcay >>> 85.22%
# Validation Accurcay >>> 80.07%
# Epoch #57
# Training Accurcay >>> 85.24%
# Validation Accurcay >>> 80.91%
# Epoch #58
# Training Accurcay >>> 85.55%
# Validation Accurcay >>> 81.13%
# Epoch #59
# Training Accurcay >>> 85.52%
# Validation Accurcay >>> 81.5%
# Epoch #60
# Training Accurcay >>> 85.52%
# Validation Accurcay >>> 80.72%
# Epoch #61
# Training Accurcay >>> 85.75%
# Validation Accurcay >>> 80.77%
# Epoch #62
# Training Accurcay >>> 85.4%
# Validation Accurcay >>> 81.59%
# Epoch #63
# Training Accurcay >>> 85.78%
# Validation Accurcay >>> 81.49%
# Epoch #64
# Training Accurcay >>> 86.13%
# Validation Accurcay >>> 81.29%
# Epoch #65
# Training Accurcay >>> 86.1%
# Validation Accurcay >>> 81.24%
# Epoch #66
# Training Accurcay >>> 85.83%
# Validation Accurcay >>> 81.26%
# Epoch #67
# Training Accurcay >>> 86.11%
# Validation Accurcay >>> 81.65%
# Epoch #68
# Training Accurcay >>> 86.14%
# Validation Accurcay >>> 81.07%
# Epoch #69
# Training Accurcay >>> 86.12%
# Validation Accurcay >>> 81.54%
# Epoch #70
# Training Accurcay >>> 86.18%
# Validation Accurcay >>> 81.46%
# Epoch #71
# Training Accurcay >>> 86.36%
# Validation Accurcay >>> 81.56%
# Epoch #72
# Training Accurcay >>> 86.16%
# Validation Accurcay >>> 81.01%
# Epoch #73
# Training Accurcay >>> 86.46%
# Validation Accurcay >>> 81.03%
# Epoch #74
# Training Accurcay >>> 86.54%
# Validation Accurcay >>> 81.35%
# Epoch #75
# Training Accurcay >>> 86.59%
# Validation Accurcay >>> 80.23%
# Epoch #76
# Training Accurcay >>> 86.68%
# Validation Accurcay >>> 81.23%
# Epoch #77
# Training Accurcay >>> 86.71%
# Validation Accurcay >>> 81.21%
# Epoch #78
# Training Accurcay >>> 86.74%
# Validation Accurcay >>> 80.94%
# Epoch #79
# Training Accurcay >>> 86.4%
# Validation Accurcay >>> 80.66%
# Epoch #80
# Training Accurcay >>> 86.92%
# Validation Accurcay >>> 81.23%
# Epoch #81
# Training Accurcay >>> 86.84%
# Validation Accurcay >>> 80.21%
# Epoch #82
# Training Accurcay >>> 86.94%
# Validation Accurcay >>> 81.29%
# Epoch #83
# Training Accurcay >>> 87.0%
# Validation Accurcay >>> 81.28%
# Epoch #84
# Training Accurcay >>> 87.0%
# Validation Accurcay >>> 81.06%
# Epoch #85
# Training Accurcay >>> 87.0%
# Validation Accurcay >>> 81.22%
# Epoch #86
# Training Accurcay >>> 87.18%
# Validation Accurcay >>> 81.58%
# Epoch #87
# Training Accurcay >>> 87.1%
# Validation Accurcay >>> 81.39%
# Epoch #88
# Training Accurcay >>> 87.1%
# Validation Accurcay >>> 81.5%
# Epoch #89
# Training Accurcay >>> 87.32%
# Validation Accurcay >>> 80.87%
# Epoch #90
# Training Accurcay >>> 87.06%
# Validation Accurcay >>> 81.22%
# Epoch #91
# Training Accurcay >>> 87.38%
# Validation Accurcay >>> 81.13%
# Epoch #92
# Training Accurcay >>> 87.48%
# Validation Accurcay >>> 81.63%
# Epoch #93
# Training Accurcay >>> 87.33%
# Validation Accurcay >>> 81.74%
# Epoch #94
# Training Accurcay >>> 87.5%
# Validation Accurcay >>> 81.69%
# Epoch #95
# Training Accurcay >>> 87.48%
# Validation Accurcay >>> 81.89%
# Epoch #96
# Training Accurcay >>> 87.95%
# Validation Accurcay >>> 81.53%
# Epoch #97
# Training Accurcay >>> 87.42%
# Validation Accurcay >>> 81.5%
# Epoch #98
# Training Accurcay >>> 87.62%
# Validation Accurcay >>> 82.27%
# Epoch #99
# Training Accurcay >>> 87.67%
# Validation Accurcay >>> 81.58%
# Epoch #100
# Training Accurcay >>> 87.54%
# Validation Accurcay >>> 81.52%

# %%
line1 = plt.plot(train_accuracies, color="r", label="Train")
line2 = plt.plot(val_accuracies, color="g", label="Validaiton")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.show()

# %%
import torchvision.models as models

resnet = models.vgg16(pretrained=True).cuda()

optimizer = torch.optim.SGD(
            augmented_net.parameters(), 
            lr=learning_rate, 
            weight_decay=weight_decay, 
            nesterov=True, 
            momentum=0.9)


EPOCHS = 100

train_accuracies = []
val_accuracies = []

best_acc = 0

for i in range(EPOCHS):
    print("Epoch #{}".format(i+1))
    num_predictions = 0
    num_correct_predictions = 0

    augmented_net.train()
    for batch in train_batches_augmented:
        data = batch.data
        labels = batch.label

        optimizer.zero_grad()

        inputs = torch.from_numpy(data).cuda()
        label = torch.from_numpy(labels).long().cuda()

        outputs = augmented_net(inputs)
        loss = criterion(outputs, label)
        loss.backward()
        optimizer.step()

        predictions = np.apply_along_axis(get_prediction, 1, outputs.cpu().detach().numpy())
        correct_predictions = np.sum(predictions == labels)
        num_correct_predictions += correct_predictions
        num_predictions += len(predictions)
    print("Training Accurcay >>> {}%".format(round(100*num_correct_predictions/num_predictions, 2)))
    train_accuracies.append(num_correct_predictions/num_predictions)
    
    # Validation during training
    num_predictions = 0
    num_correct_predictions = 0

    augmented_net.eval()
    with torch.no_grad():
        for val_batch in val_batches:
            data = val_batch.data
            labels = val_batch.label

            inputs = torch.from_numpy(data).cuda()

            outputs = augmented_net(inputs)
            predictions = np.apply_along_axis(get_prediction, 1, outputs.cpu())
            correct_predictions = np.sum(predictions == labels)
            num_correct_predictions += correct_predictions
            num_predictions += len(predictions)
        if num_correct_predictions/num_predictions > best_acc:
            torch.save(resnet.state_dict(), "VGG16.net".format(i, round(100*num_correct_predictions/num_predictions)))
            best_acc = num_correct_predictions/num_predictions
    print("Validation Accurcay >>> {}%".format(round(100*num_correct_predictions/num_predictions, 2)))
    val_accuracies.append(num_correct_predictions/num_predictions)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# HBox(children=(FloatProgress(value=0.0, max=553433881.0), HTML(value='')))
# Epoch #1
# Training Accurcay >>> 88.1%
# Validation Accurcay >>> 81.69%
# Epoch #2
# Training Accurcay >>> 88.2%
# Validation Accurcay >>> 80.75%
# Epoch #3
# Training Accurcay >>> 88.4%
# Validation Accurcay >>> 81.28%
# Epoch #4
# Training Accurcay >>> 88.0%
# Validation Accurcay >>> 80.33%
# Epoch #5
# Training Accurcay >>> 88.26%
# Validation Accurcay >>> 81.74%
# Epoch #6
# Training Accurcay >>> 88.24%
# Validation Accurcay >>> 81.46%
# Epoch #7
# Training Accurcay >>> 88.5%
# Validation Accurcay >>> 80.83%
# Epoch #8
# Training Accurcay >>> 88.06%
# Validation Accurcay >>> 81.69%
# Epoch #9
# Training Accurcay >>> 88.32%
# Validation Accurcay >>> 82.25%
# Epoch #10
# Training Accurcay >>> 88.6%
# Validation Accurcay >>> 81.75%
# Epoch #11
# Training Accurcay >>> 88.3%
# Validation Accurcay >>> 81.63%
# Epoch #12
# Training Accurcay >>> 88.33%
# Validation Accurcay >>> 80.94%
# Epoch #13
# Training Accurcay >>> 88.49%
# Validation Accurcay >>> 81.26%
# Epoch #14
# Training Accurcay >>> 88.35%
# Validation Accurcay >>> 81.81%
# Epoch #15
# Training Accurcay >>> 88.44%
# Validation Accurcay >>> 81.45%
# Epoch #16
# Training Accurcay >>> 88.55%
# Validation Accurcay >>> 81.51%
# Epoch #17
# Training Accurcay >>> 88.66%
# Validation Accurcay >>> 81.57%
# Epoch #18
# Training Accurcay >>> 88.5%
# Validation Accurcay >>> 81.74%
# Epoch #19
# Training Accurcay >>> 88.75%
# Validation Accurcay >>> 81.7%
# Epoch #20
# Training Accurcay >>> 88.67%
# Validation Accurcay >>> 81.8%
# Epoch #21
# Training Accurcay >>> 88.79%
# Validation Accurcay >>> 82.06%
# Epoch #22
# Training Accurcay >>> 88.65%
# Validation Accurcay >>> 81.48%
# Epoch #23
# Training Accurcay >>> 88.48%
# Validation Accurcay >>> 81.37%
# Epoch #24
# Training Accurcay >>> 88.68%
# Validation Accurcay >>> 81.82%
# Epoch #25
# Training Accurcay >>> 88.56%
# Validation Accurcay >>> 81.7%
# Epoch #26
# Training Accurcay >>> 88.68%
# Validation Accurcay >>> 81.68%
# Epoch #27
# Training Accurcay >>> 88.61%
# Validation Accurcay >>> 81.89%
# Epoch #28
# Training Accurcay >>> 88.76%
# Validation Accurcay >>> 81.92%
# Epoch #29
# Training Accurcay >>> 88.68%
# Validation Accurcay >>> 81.76%
# Epoch #30
# Training Accurcay >>> 88.68%
# Validation Accurcay >>> 81.24%
# Epoch #31
# Training Accurcay >>> 88.96%
# Validation Accurcay >>> 81.96%
# Epoch #32
# Training Accurcay >>> 88.68%
# Validation Accurcay >>> 82.09%
# Epoch #33
# Training Accurcay >>> 88.78%
# Validation Accurcay >>> 81.87%
# Epoch #34
# Training Accurcay >>> 88.77%
# Validation Accurcay >>> 82.17%
# Epoch #35
# Training Accurcay >>> 88.98%
# Validation Accurcay >>> 82.07%
# Epoch #36
# Training Accurcay >>> 88.88%
# Validation Accurcay >>> 81.85%
# Epoch #37
# Training Accurcay >>> 88.91%
# Validation Accurcay >>> 83.13%
# Epoch #38
# Training Accurcay >>> 88.72%
# Validation Accurcay >>> 82.44%
# Epoch #39
# Training Accurcay >>> 89.0%
# Validation Accurcay >>> 82.08%
# Epoch #40
# Training Accurcay >>> 88.85%
# Validation Accurcay >>> 81.86%
# Epoch #41
# Training Accurcay >>> 89.07%
# Validation Accurcay >>> 82.4%
# Epoch #42
# Training Accurcay >>> 88.89%
# Validation Accurcay >>> 82.21%
# Epoch #43
# Training Accurcay >>> 89.32%
# Validation Accurcay >>> 82.4%
# Epoch #44
# Training Accurcay >>> 88.99%
# Validation Accurcay >>> 82.11%
# Epoch #45
# Training Accurcay >>> 89.1%
# Validation Accurcay >>> 82.0%
# Epoch #46
# Training Accurcay >>> 89.14%
# Validation Accurcay >>> 81.0%
# Epoch #47
# Training Accurcay >>> 88.86%
# Validation Accurcay >>> 81.73%
# Epoch #48
# Training Accurcay >>> 88.98%
# Validation Accurcay >>> 81.34%
# Epoch #49
# Training Accurcay >>> 88.88%
# Validation Accurcay >>> 82.0%
# Epoch #50
# Training Accurcay >>> 89.0%
# Validation Accurcay >>> 81.94%
# Epoch #51
# Training Accurcay >>> 89.3%
# Validation Accurcay >>> 81.61%
# Epoch #52
# Training Accurcay >>> 88.81%
# Validation Accurcay >>> 81.49%
# Epoch #53
# Training Accurcay >>> 89.32%
# Validation Accurcay >>> 81.97%
# Epoch #54
# Training Accurcay >>> 89.11%
# Validation Accurcay >>> 81.69%
# Epoch #55
# Training Accurcay >>> 89.2%
# Validation Accurcay >>> 81.58%
# Epoch #56
# Training Accurcay >>> 89.33%
# Validation Accurcay >>> 81.6%
# Epoch #57
# Training Accurcay >>> 89.23%
# Validation Accurcay >>> 81.49%
# Epoch #58
# Training Accurcay >>> 89.29%
# Validation Accurcay >>> 81.96%
# Epoch #59
# Training Accurcay >>> 89.02%
# Validation Accurcay >>> 80.71%
# Epoch #60
# Training Accurcay >>> 89.41%
# Validation Accurcay >>> 82.02%
# Epoch #61
# Training Accurcay >>> 89.23%
# Validation Accurcay >>> 81.32%
# Epoch #62
# Training Accurcay >>> 89.26%
# Validation Accurcay >>> 82.41%
# Epoch #63
# Training Accurcay >>> 89.36%
# Validation Accurcay >>> 81.71%
# Epoch #64
# Training Accurcay >>> 89.21%
# Validation Accurcay >>> 82.46%
# Epoch #65
# Training Accurcay >>> 89.06%
# Validation Accurcay >>> 81.61%
# Epoch #66
# Training Accurcay >>> 89.49%
# Validation Accurcay >>> 81.73%
# Epoch #67
# Training Accurcay >>> 89.4%
# Validation Accurcay >>> 81.44%
# Epoch #68
# Training Accurcay >>> 89.41%
# Validation Accurcay >>> 82.18%
# Epoch #69
# Training Accurcay >>> 89.42%
# Validation Accurcay >>> 81.05%
# Epoch #70
# Training Accurcay >>> 89.32%
# Validation Accurcay >>> 81.82%
# Epoch #71
# Training Accurcay >>> 89.65%
# Validation Accurcay >>> 82.08%
# Epoch #72
# Training Accurcay >>> 89.33%
# Validation Accurcay >>> 81.75%
# Epoch #73
# Training Accurcay >>> 89.4%
# Validation Accurcay >>> 81.73%
# Epoch #74
# Training Accurcay >>> 89.49%
# Validation Accurcay >>> 82.22%
# Epoch #75
# Training Accurcay >>> 89.4%
# Validation Accurcay >>> 81.73%
# Epoch #76
# Training Accurcay >>> 89.42%
# Validation Accurcay >>> 82.49%
# Epoch #77
# Training Accurcay >>> 89.52%
# Validation Accurcay >>> 82.05%
# Epoch #78
# Training Accurcay >>> 89.38%
# Validation Accurcay >>> 82.4%
# Epoch #79
# Training Accurcay >>> 89.47%
# Validation Accurcay >>> 82.96%
# Epoch #80
# Training Accurcay >>> 89.38%
# Validation Accurcay >>> 81.67%
# Epoch #81
# Training Accurcay >>> 89.55%
# Validation Accurcay >>> 82.83%
# Epoch #82
# Training Accurcay >>> 89.44%
# Validation Accurcay >>> 81.95%
# Epoch #83
# Training Accurcay >>> 89.26%
# Validation Accurcay >>> 82.03%
# Epoch #84
# Training Accurcay >>> 89.33%
# Validation Accurcay >>> 81.37%
# Epoch #85
# Training Accurcay >>> 89.67%
# Validation Accurcay >>> 82.09%
# Epoch #86
# Training Accurcay >>> 89.6%
# Validation Accurcay >>> 82.08%
# Epoch #87
# Training Accurcay >>> 89.4%
# Validation Accurcay >>> 81.44%
# Epoch #88
# Training Accurcay >>> 89.58%
# Validation Accurcay >>> 82.01%
# Epoch #89
# Training Accurcay >>> 89.49%
# Validation Accurcay >>> 81.49%
# Epoch #90
# Training Accurcay >>> 89.45%
# Validation Accurcay >>> 82.31%
# Epoch #91
# Training Accurcay >>> 89.45%
# Validation Accurcay >>> 81.66%
# Epoch #92
# Training Accurcay >>> 89.6%
# Validation Accurcay >>> 82.21%
# Epoch #93
# Training Accurcay >>> 89.53%
# Validation Accurcay >>> 82.07%
# Epoch #94
# Training Accurcay >>> 89.6%
# Validation Accurcay >>> 81.93%
# Epoch #95
# Training Accurcay >>> 89.83%
# Validation Accurcay >>> 81.84%
# Epoch #96
# Training Accurcay >>> 89.5%
# Validation Accurcay >>> 81.8%
# Epoch #97
# Training Accurcay >>> 89.5%
# Validation Accurcay >>> 82.05%
# Epoch #98
# Training Accurcay >>> 89.57%
# Validation Accurcay >>> 82.21%
# Epoch #99
# Training Accurcay >>> 89.6%
# Validation Accurcay >>> 82.18%
# Epoch #100
# Training Accurcay >>> 89.82%
# Validation Accurcay >>> 82.16%

# %%
line1 = plt.plot(train_accuracies, color="r", label="Train")
line2 = plt.plot(val_accuracies, color="g", label="Validaiton")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

plt.show()
